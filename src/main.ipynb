# %%
from __future__ import annotations

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext tensorboard

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

# %%
import sys
import math
import logging
import typing
from datetime import datetime
from pathlib import Path
from os import PathLike

import mlflow

if typing.TYPE_CHECKING:
    from os import PathLike

# %%
from setup_mlflow import setup_mlflow

# %%
mlflow.set_experiment(experiment_id="0")
mlflow.pytorch.autolog()

# %%
from main import plot_learning_rates, run_training

# %%
_handler = logging.StreamHandler(sys.stdout)
_handler.setFormatter(
    logging.Formatter(
        "%(asctime)s - %(name)s - %(levelname)s - %(message)s", datefmt="%H:%M:%S'"
    )
)
_logger = logging.getLogger("adaptive_milling_training")
for _ in _logger.handlers:
    _logger.removeHandler(_)
_logger.setLevel(logging.DEBUG)
_logger.addHandler(_handler)

# %%
test_csv = "/ceph/groups/structbio/adaptive_milling_project/2024labels_new/test.csv"
all_files_csv = (
    "/ceph/groups/structbio/adaptive_milling_project/2024labels_new/all_files.csv"
)

# %%
plot_learning_rates(
    test_csv, models_to_ignore=["unet", "dynunet", "segresnetds2", "segresnetvae"]
)

# %%
run_training(all_files_csv, model_name="segresnet", learning_rate=9e-5, epochs=30)
